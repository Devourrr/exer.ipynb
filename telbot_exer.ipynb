# %%
import pyttsx3
import telebot
import random
import selenium
from urllib import parse
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

TOKEN = '1795391045:AAFsmAKo_ResztkMR96grDLq-Ftyf1luPmY'
bot = telebot.TeleBot(TOKEN)
chat_id = '1756656744'


@bot.message_handler(commands = ['유산소', '무산소'])
def health_choice(message):
    health = message.text.split("/")[1]
    weader = "구름 맑음"
    driver = webdriver.Chrome('chromedriver.exe')
    engine = pyttsx3.init()
    # 날씨 데이터를 받을 때 공백이 있다는 가정하에 공백 기준으로 스플릿
    weader_split = weader.split(' ') # 스플릿한 데이터 변수에 리스트로 저장
    if health == '유산소':
        inside_health = ['점핑잭', '버피 테스트', '계단 오르기','스트레칭']
        outside_health = ['걷기', '조깅', '달리기', '자전거']
        if '비' in weader_split[0:]: # 변수 리스트에 담겨있는 데이터 중 '비'라는 문자(날씨)가 있다면 실내 운동, 없다면 실외 운동
            health_result = random.choice(inside_health)
            # bot.send_message(chat_id, health_result)
            if inside_health == inside_health[0]:
                driver.get(f'https://www.google.com/search?q={inside_health[0]} 효과')
                jump = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/div/ul').text
                jm_info = f'비가 오늘 날엔 실내에서 할 수 있는 {health_result}를 추천합니다. 점핑잭 운동효과, {jump}'
                engine.setProperty('rate',150)
                engine.save_to_file(jm_info,'jm_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,jm_info)
                bot.send_audio(chat_id=chat_id, audio=open('jm_info.mp3','rb'))
    
            elif inside_health == inside_health[1]:
                driver.get(f'https://www.google.com/search?q={inside_health[1]} 효과')
                buf = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/span[1]/span').text
                bf_info = f'비가 오늘 날엔 실내에서 할 수 있는 {health_result}를 추천합니다. 버피테스트 운동효과, {buf}'
                engine.setProperty('rate',150)
                engine.save_to_file(bf_info,'bf_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,bf_info)
                bot.send_audio(chat_id=chat_id, audio=open('bf_info.mp3','rb'))

            elif inside_health == inside_health[2]:
                driver.get(f'https://www.google.com/search?q={inside_health[2]} 효과')
                stair = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/div[2]/ul').text
                str_info = '비가 오늘 날엔 실내에서 할 수 있는 {health_result}를 추천합니다. 계단 오르기 운동효과, {stair}'
                engine.setProperty('rate',150)
                engine.save_to_file(str_info,'str_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,str_info)
                bot.send_audio(chat_id=chat_id, audio=open('str_info.mp3','rb'))

            else:
                driver.get(f'https://www.google.com/search?q={inside_health[3]} 효과')
                strch =driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[1]/div/span[1]/span').text
                sr_info = f'비가 오늘 날엔 실내에서 할 수 있는 {health_result}을 추천합니다. 스트레칭 운동 효과, {strch}'
                engine.setProperty('rate',150)
                engine.save_to_file(sr_info,'sr_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,sr_info)
                bot.send_audio(chat_id=chat_id, audio=open('sr_info.mp3','rb'))
                
        else:
            health_result = random.choice(outside_health)
            if health_result == outside_health[0]:
                driver.get(f'https://www.google.com/search?q={outside_health[0]} 효과')
                walk = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/div[2]/ul').text
                wk_info = f'구름 맑은 날엔 야외 {health_result}운동을 추가합니다. 걷기 운동 효과 {walk}'
                engine.setProperty('rate',150)
                engine.save_to_file(wk_info,'wk_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,wk_info)
                bot.send_audio(chat_id=chat_id, audio=open('wk_info.mp3','rb'))
            elif health_result == outside_health[1]:
                driver.get(f'https://www.google.com/search?q={outside_health[1]} 효과')
                jog = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/div[2]/ul').text
                jg_info = f'구름 맑은 날엔 야외 {health_result}을 추천합니다. 조깅 운동효과, {jog}'
                engine.setProperty('rate',150)
                engine.save_to_file(jg_info,'jg_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,jg_info)
                bot.send_audio(chat_id=chat_id, audio=open('jg_info.mp3','rb'))
            elif health_result == outside_health[2]:
                driver.get(f'https://www.google.com/search?q={outside_health[2]} 효과')
                run = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[1]/div/span[1]/span').text
                rn_info = f'구름 맑은 날엔 야외에서 {health_result}를 추천합니다. 달리기 운동 효과, {run}'
                engine.setProperty('rate',150)
                engine.save_to_file(rn_info,'rn_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,rn_info)
                bot.send_audio(chat_id=chat_id, audio=open('rn_info.mp3','rb'))
            
            else:
                driver.get(f'https://www.google.com/search?q={outside_health[3]} 효과')
                bic = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[1]/div/div[2]/ul').text
                bc_info = f'구름 맑은 날엔 야외에서 {health_result}운동을 추천합니다. 자전거 운동 효과. {bic}'
                engine.setProperty('rate',150)
                engine.save_to_file(bc_info,'bc_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,bc_info)
                bot.send_audio(chat_id=chat_id, audio=open('bc_info.mp3','rb'))
                
    else:
        cardio_training = ['팔굽혀펴기','윗몸일으키기','턱걸이','플랭크'] # '팔굽혀펴기', '윗몸일으키기', ,'턱걸이','플랭크 등등
        weight_training = ['벤치프레스','데드리프트','스쿼트','밀리터리프레스'] # 벤치프레스,데드리프트, 스쿼트, 밀리터리프레스 등등
        if '비' in weader_split[0:]: # 변수 리스트에 담겨있는 데이터 중 '비'라는 문자(날씨)가 있다면 실내 맨몸운동, 없다면 실외(헬스장) 기구운동
            health_result = random.choice(cardio_training) # 밖에 나가지 않고 실내 맨몸운동
            if health_result == cardio_training[0]:
                driver.get(f'https://www.google.com/search?q={cardio_training[0]} 효과')
                pus = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/div[2]/ul').text
                pu_info = f'비가 오는 날엔 실내에서 {health_result}를 추천합니다. 팔굽혀펴기 운동 효과, {pus}'
                engine.setProperty('rate',150)
                engine.save_to_file(pu_info,'pu_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,pu_info)
                bot.send_audio(chat_id=chat_id, audio=open('pu_info.mp3','rb'))

            elif health_result == cardio_training[1]:
                driver.get(f'https://www.google.com/search?q={cardio_training[1]} 효과')
                stup = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/span[1]/span').text
                st_info = f'비가 오는 날엔 실내에서 {health_result}를 추천합니다. 윗몸일으키기 운동 효과, {stup}'
                engine.setProperty('rate',150)
                engine.save_to_file(st_info,'st_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,st_info)
                bot.send_audio(chat_id=chat_id, audio=open('st_info.mp3','rb'))

            elif health_result == cardio_training[2]:
                driver.get(f'https://www.google.com/search?q={cardio_training[2]} 효과')
                pul = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/span[1]/span').text
                pl_info = f'비가 오는 날엔 실내에서 {health_result}를 추천합니다. 턱걸이 운동 효과, {pul}'
                engine.setProperty('rate',150)
                engine.save_to_file(pl_info,'pl_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,pl_info)
                bot.send_audio(chat_id=chat_id, audio=open('pl_info.mp3','rb'))

            else:
                driver.get(f'https://www.google.com/search?q={cardio_training[3]} 효과')
                plk = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/span[1]/span').text
                plk_info = f'비가 오는 날엔 실내에서 {health_result}를 추천합니다. 플랭크 운동 효과, {plk}'
                engine.setProperty('rate',150)
                engine.save_to_file(plk_info,'plk_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,plk_info)
                bot.send_audio(chat_id=chat_id, audio=open('plk_info.mp3','rb'))

           
        else:
            health_result = random.choice(weight_training) # 헬스장에 나가서 실외 기구운동
            if health_result == weight_training[0]:
                driver.get(f'https://www.google.com/search?q={weight_training[0]} 효과')
                bnp = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/span[1]/span').text
                bp_info = f'구름 맑은 날엔 헬스장에 가보세요, {health_result}를 추천합니다. 벤치 프레스 운동 효과, {bnp}'
                engine.setProperty('rate',150)
                engine.save_to_file(bp_info,'bp_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,bp_info)
                bot.send_audio(chat_id=chat_id, audio=open('bp_info.mp3','rb'))

            elif health_result == weight_training[1]:
                driver.get(f'https://www.google.com/search?q={weight_training[1]} 효과')
                dlft = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/span[1]/span').text
                dl_info = f'구름 맑은 날엔 헬스장에 가보세요, {health_result}를 추천합니다. 데드리프트 운동 효과, {dlft}'
                engine.setProperty('rate',150)
                engine.save_to_file(dl_info,'dl_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,dl_info)
                bot.send_audio(chat_id=chat_id, audio=open('dl_info.mp3','rb'))

            elif health_result == weight_training[2]:
                driver.get(f'https://www.google.com/search?q={weight_training[2]} 효과')
                squ =driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/span[1]/span').text
                sq_info = f'구름 맑은 날엔 헬스장에 가보세요, {health_result}를 추천합니다. 스쿼트 운동 효과, {squ}'
                engine.setProperty('rate',150)
                engine.save_to_file(sq_info,'sq_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,sq_info)
                bot.send_audio(chat_id=chat_id, audio=open('sq_info.mp3','rb'))

            else:
                driver.get(f'https://www.google.com/search?q={weight_training[3]} 효과')
                mlp = driver.find_element(By.XPATH,'//*[@id="rso"]/div[1]/div/div[1]/div/div[1]/div/div[2]/div/span[1]/span').text
                mp_info = f'구름 맑은 날엔 헬스장에 가보세요, {health_result}를 추천합니다. 밀리터리 프레스 운동 효과, {mlp}'
                engine.setProperty('rate',150)
                engine.save_to_file(mp_info,'mp_info.mp3')
                engine.runAndWait()
                pyttsx3.init(driverName='sapi5') 
                time.sleep(3)
                bot.reply_to(message,mp_info)
                bot.send_audio(chat_id=chat_id, audio=open('mp_info.mp3','rb'))
                
                
bot.polling()
